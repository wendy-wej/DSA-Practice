# %%
## Constructing a node class

class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self): ##TC: O(1)
        self.head= None
        self.tail= None
        self.length = 0
      
    ##Inserting at the end
    def append(self, value): ##TC: O(1)
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length +=1
        
    def __str__(self): ## used to print ##TC: O(N)
        current_node = self.head
        result = ''
        while current_node is not None:
            result += str(current_node.value)
            if current_node.next is not None:
                result += ' -> '
            current_node = current_node.next
        return result
    
    def prepend(self, value): ##TC: O(1)
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length +=1
        
    def insert(self, value, index): ##TC: O(N)
        new_node = Node(value)
        if index < 0 or index > self.length:
            return False
        if self.head is None: ## edgecase: linkedlist is empty
            self.head = new_node
            self.tail = new_node
        elif index ==0: ## edgecase inserting at the beginning of a linkedlist
            new_node.next = self.head
            self.head = new_node
        else:
            current_node = self.head
            for _ in range(index-1):
                current_node = current_node.next  
            new_node.next = current_node.next
            current_node.next = new_node
        self.length +=1
        return True
    
    def traverse(self): ##TC: O(N)
        current_node = self.head
        while current_node:
            print(current_node.value)
            current_node = current_node.next
            
    def search(self, target): ##TC: O(N)
        current_node = self.head
        while current_node:
            if current_node.value == target:
                return index
            current_node = current_node.next
        return -1
    
    def get(self, index): ##TC: O(N)
        if index == -1:
            return self.tail
        if index < -1 or index >= self.length:
            return None
        current_node = self.head
        for _ in range(index):
            current_node = current_node.next
        return current_node
  
    def setter(self, index, value): ##TC: O(N)
        current_node = self.get(index)
        #print("The index I got is", current_node.value)
        if current_node is not None:
            current_node.value = value
            return True
        return False
    
    def pop_head(self): ##TC: O(1)
        if self.length == 0:
            return None
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            popped_node = self.head
            self.head = popped_node.next
            popped_node.next = None
        self.length -=1
        return popped_node  
    
    def pop_tail(self): ##TC: O(N)
        popped_node = self.tail
        if self.length == 0:
            return None
        if self.length == 1:
            self.head = None
            self.tail = None
        curr = self.head
        while temp.next is not self.tail:
            curr = curr.next
        self.tail = temp
        temp.next = None
        self.length -=1
        return popped_node
    
    def remove(self, index): ##TC: O(N)
        if index == 0:
            return self.pop_head()
        if index == -1 or index == self.length-1:
            return self.pop_tail()
        if index < -1 or index > self.length:
            return None
        prev_node = self.get(index-1)
        popped_node = prev_node.next
        prev_node.next = popped_node.next
        popped_node.next = None
        self.length -=1
        return popped_node
    
    def delete_all(self): #Time complexity = O(1)
        self.head = None
        self.tail = None
        self.length = 0
        
    
        
        

new_linkedlist = LinkedList() ##Time and space complexity is O(1)
new_linkedlist.insert(1,0)
new_linkedlist.append(10)
new_linkedlist.append(20)
new_linkedlist.append(30)
new_linkedlist.prepend(40)
new_linkedlist.insert(15,2)
#new_linkedlist.traverse()
print(new_linkedlist)
print(new_linkedlist.get(3))
print(new_linkedlist.setter(1, 80))
print(new_linkedlist)


#     def setter(self, value, index):
#         if index < 0 or index >= self.length:
#             return None 
#         current_node = self.head
#         for _ in range(index):
#             current_node = current_node.next
#         current_node.value = value
#         return current_node.value
    
# MY GET FUNCTION
#     def get(self, index):
#         current_node = self.head
#         for i in range(self.length -1):
#             if i == index:
#                 return current_node.value
#             current_node = current_node.next
#         return False
# Out:
# 40 -> 1 -> 15 -> 10 -> 20 -> 30
# ...
# True
# 40 -> 80 -> 15 -> 10 -> 20 -> 30

# %%
class ListNode:  
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        length = max(len(list1, list2)        
        i= 0
        j= 0
                     
        if list1[i] > list2[j]:
            temp = ListNode(list2[j])
            j+=1                
        else:
            temp = ListNode(list1[i])
            i+=1
                     
        while (i < len(list1)) and (j < len(list2)):
            if list1[i] > list2[j]:
            temp.next = list2[j]
            j+=1                
        else:
            temp.next = list2[j]
            i+=1
# Out:
#   Cell In[29], line 8
#     i= 0
#     ^
# SyntaxError: invalid syntax

# %%
# Definition for singly-linked list.
class ListNode:  
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def mergeTwoLists(self, list1, list2):
        dummy = ListNode(-1)
        curr_node = dummy
    
    while list1 and list2:
        if list1.val <= list2.val:
            curr_node = list1.val
            list1 =list1.next
        else:
            curr_node = list2.val
            list2 =list2.next
    
    def __str__(self): ## used to print ##TC: O(N)
        current_node = self.head
        result = ''
        while current_node is not None:
            result += str(current_node.value)
            if current_node.next is not None:
                result += ' -> '
            current_node = current_node.next
        return result

mergeTwoLists([1,2,4], [1,3,4])
print(curr_node)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 6
#       4         self.val = val
#       5         self.next = next
# ----> 6 class Solution:
#       7     def mergeTwoLists(self, list1, list2):
#       8         dummy = ListNode(-1)
#
# Cell In[32], line 11, in Solution()
#       8     dummy = ListNode(-1)
#       9     curr_node = dummy
# ---> 11 while list1 and list2:
#      12     if list1.val <= list2.val:
#      13         curr_node = list1.val
#
# NameError: name 'list1' is not defined
